# %% [markdown]
# # Image Classification with PyTorch

# %% [markdown]
# ## Data loading

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
import torchvision
from torchvision import datasets, transforms

# %%
# torchvision contains convinience functions for popular datasets
ds_train = datasets.MNIST('data', train=True, download=True)

# %% [markdown]
# Each sample is a 28x28 image

# %%
# if we index this dataset, we get a single data point: a PIL image and an Integer
print(ds_train[0])
ds_train[0][0].resize((120,120))
# Out:
# (<PIL.Image.Image image mode=L size=28x28 at 0x169716F50>, 5)
# <PIL.Image.Image image mode=L size=120x120>

# %% [markdown]
# Let's transform the data to something that our Pytorch models will understand
# for this purpose, we can supply a transform function to the datase

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
])
ds_train = datasets.MNIST('data', train=True, download=True, transform=transform)

# %% [markdown]
# The image is now a `torch.Tensor`

# %%
type(ds_train[0][0])
# Out:
# torch.Tensor

# %% [markdown]
# The normalization is something you learned about in the lecture. Normalizing with $\mu=0, \sigma=1$ corresponds to no normalization. Let's compute the proper normalization constants!

# %%
# lets get only the images 
ims_train = ds_train.data
ims_train = ims_train.float() / 255.

# %%
#########################################################################
# TODO: calculate the mean and std of MNIST images
# hint: to look for operations on pytorch tensor, refer to the official PyTorch docs 
# https://pytorch.org/docs/stable/
#########################################################################
# print([torch.mean(ims_train[i,:]) for i in range(ims_train.shape[0])])
mu = torch.mean(ims_train)
std = torch.std(ims_train)

print(mu, mu.shape)
print(std)
# Out:
# tensor(0.1307) torch.Size([])
# tensor(0.3081)

# %% [markdown]
# We normalize the data as below.

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mu, std)
])
ds_train = datasets.MNIST('data', train=True, download=True, transform=transform)
ds_test = datasets.MNIST('data', train=False, download=True, transform=transform)

# %%
ims_train = ds_train.data
ims_train = ims_train.float() / 255.
mu = torch.mean(ims_train)
std = torch.std(ims_train)

print(mu)
print(std)
# Out:
# tensor(0.1307)
# tensor(0.3081)

# %%
ds_train[0][0].min(), ds_train[0][0].max()
# Out:
# (tensor(-0.4241), tensor(2.8215))

# %% [markdown]
# Next, we want to receive mini-batches, not only single data points.
# We use PyTorch's DataLoader class. Build a dataloader with a batch size of 64 and 4 workers (number of subprocess that peform the dataloading). Important: you need to shuffle the training data, not the test data.
#
# **NOTE**: if you encounter some unexpected errors in data loading, try setting `NUM_WORKERS = 0`

# %%
BATCH_SIZE = 64
NUM_WORKERS = 4
#########################################################################
# TODO: Build a dataloader for both train and test data.
#########################################################################
dl_train = DataLoader(ds_train, batch_size=64, shuffle=True, num_workers=4)
dl_test = DataLoader(ds_test, batch_size=64, shuffle=True, num_workers=4)

# %% [markdown]
# ## MLP in Pytorch
#
# Ok, the dataloading works. Let's build our model, PyTorch makes this very easy. We will build replicate the model from our last exercises. However, now, we add another variable called `nLayer` that indicates how many linear layers that in your network. Please adapt your code from last exercise accordingly to allow different number of layers.

# %%
# These are the parameters to be used
nInput = 784
nOutput = 10
nLayer = 2
nHidden = 16
act_fn = nn.ReLU()

# %%
#########################################################################
# TODO: Implement the __init__ of the MLP class. 
# insert the activation after every linear layer. Important: the number of 
# hidden layers should be variable!
#########################################################################

class MLP(nn.Module):
    def __init__(self, nInput, nOutput, nLayer, nHidden, act_fn):
        super(MLP, self).__init__()
        layers = [] 
        
        ##### implement this part #####
        layers.append(nn.Linear(nInput, nHidden))
        layers.append(act_fn)
        for i in range(nLayer-1):
            layers.append(nn.Linear(nHidden, nHidden))
            layers.append(act_fn)
        layers.append(nn.Linear(nHidden, nOutput))
        
        ###############################
        
        self.model = nn.Sequential(*layers)

    def forward(self, x):
        x = torch.flatten(x, 1)
        return self.model(x)

# %%
# Let's test if the forward pass works
# this should print torch.Size([1, 10])
t = torch.randn(1,1,28,28)
mlp = MLP(nInput, nOutput, nLayer, nHidden, act_fn)
mlp(t).shape
# Out:
# torch.Size([1, 10])

# %%
mlp
# Out:
# MLP(
#   (model): Sequential(
#     (0): Linear(in_features=784, out_features=16, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=16, out_features=16, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=16, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# We already implemented the test function for you

# %%
def test(model, dl_test, device='cpu'):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in dl_test:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.cross_entropy(output, target, reduction='sum').item()  # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(dl_test.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.3f}%)\n'.format(
        test_loss, correct, len(dl_test.dataset),
        100. * correct / len(dl_test.dataset)))

# %% [markdown]
# Now you only need to implement the training and you are good to go

# %%
#########################################################################
# TODO: Implement the missing part of the training function. As a loss function we want to use cross entropy
# It can be called with F.cross_entropy().
# Hint: Pass through the model -> Backpropagate gradients -> Take gradient step
#########################################################################
def train(model, dl_train, optimizer, epoch, log_interval=100, device='cpu'):
    model.train()
    correct = 0
    for batch_idx, (data, target) in enumerate(dl_train):
        data, target = data.to(device), target.to(device)
        
        # first we need to zero the gradient, otherwise PyTorch would accumulate them
        optimizer.zero_grad()         
        
        ##### implement this part #####
        
        # pass through the model
        output = model(data)

        # calculate the loss
        loss = F.cross_entropy(output, target)

        # backpropagate the gradients
        loss.backward()

        # take gradient step
        optimizer.step()
        

        ###############################

        # stats
        pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
        correct += pred.eq(target.view_as(pred)).sum().item()

        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(dl_train.dataset),
                100. * batch_idx / len(dl_train), loss.item()))

    print('\nTrain set: Average loss: {:.4f}, Accuracy: {}/{} ({:.1f}%)\n'.format(
        loss, correct, len(dl_train.dataset),
        100. * correct / len(dl_train.dataset)))

# %% [markdown]
# Ok, the setup is almost done. The onoly missing part is the optimizer. We are going to use Adam.

# %%
# reinitialize the mlp, so we can play with parameters right here
mlp = MLP(nInput, nOutput, nLayer, nHidden, act_fn)
optimizer = optim.Adam(mlp.parameters())

# %%
epochs = 10
for epoch in range(1, epochs + 1):
    train(mlp, dl_train, optimizer, epoch, log_interval=100)
    test(mlp, dl_test)

print ('Training is finished.')
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.316887
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 0.791241
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.508089
# Train Epoch: 1 [19200/60000 (32%)]	Loss: 0.406540
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.439426
# Train Epoch: 1 [32000/60000 (53%)]	Loss: 0.354045
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.383155
# Train Epoch: 1 [44800/60000 (75%)]	Loss: 0.300555
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.238718
# Train Epoch: 1 [57600/60000 (96%)]	Loss: 0.215504
#
# Train set: Average loss: 0.1743, Accuracy: 50930/60000 (84.9%)
#
#
# Test set: Average loss: 0.2710, Accuracy: 9165/10000 (91.650%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.156671
# Train Epoch: 2 [6400/60000 (11%)]	Loss: 0.396296
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.320172
# Train Epoch: 2 [19200/60000 (32%)]	Loss: 0.251689
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.179063
# Train Epoch: 2 [32000/60000 (53%)]	Loss: 0.237490
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 0.239197
# Train Epoch: 2 [44800/60000 (75%)]	Loss: 0.318653
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.196872
# Train Epoch: 2 [57600/60000 (96%)]	Loss: 0.081668
#
# Train set: Average loss: 0.1201, Accuracy: 55782/60000 (93.0%)
#
#
# Test set: Average loss: 0.2080, Accuracy: 9362/10000 (93.620%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.275393
# Train Epoch: 3 [6400/60000 (11%)]	Loss: 0.244101
# Train Epoch: 3 [12800/60000 (21%)]	Loss: 0.244842
# Train Epoch: 3 [19200/60000 (32%)]	Loss: 0.247110
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.228157
# Train Epoch: 3 [32000/60000 (53%)]	Loss: 0.306410
# Train Epoch: 3 [38400/60000 (64%)]	Loss: 0.198935
# Train Epoch: 3 [44800/60000 (75%)]	Loss: 0.473020
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.143378
# Train Epoch: 3 [57600/60000 (96%)]	Loss: 0.243277
#
# Train set: Average loss: 0.0500, Accuracy: 56672/60000 (94.5%)
#
#
# Test set: Average loss: 0.1728, Accuracy: 9475/10000 (94.750%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.219491
# Train Epoch: 4 [6400/60000 (11%)]	Loss: 0.095193
# Train Epoch: 4 [12800/60000 (21%)]	Loss: 0.261605
# Train Epoch: 4 [19200/60000 (32%)]	Loss: 0.203875
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.225274
# Train Epoch: 4 [32000/60000 (53%)]	Loss: 0.057602
# Train Epoch: 4 [38400/60000 (64%)]	Loss: 0.499757
# Train Epoch: 4 [44800/60000 (75%)]	Loss: 0.138387
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.081848
# Train Epoch: 4 [57600/60000 (96%)]	Loss: 0.255253
#
# Train set: Average loss: 0.1156, Accuracy: 57030/60000 (95.0%)
#
#
# Test set: Average loss: 0.1614, Accuracy: 9505/10000 (95.050%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.149794
# Train Epoch: 5 [6400/60000 (11%)]	Loss: 0.056460
# Train Epoch: 5 [12800/60000 (21%)]	Loss: 0.071598
# Train Epoch: 5 [19200/60000 (32%)]	Loss: 0.086666
# Train Epoch: 5 [25600/60000 (43%)]	Loss: 0.112900
# Train Epoch: 5 [32000/60000 (53%)]	Loss: 0.144811
# Train Epoch: 5 [38400/60000 (64%)]	Loss: 0.045141
# Train Epoch: 5 [44800/60000 (75%)]	Loss: 0.062615
# Train Epoch: 5 [51200/60000 (85%)]	Loss: 0.079325
# Train Epoch: 5 [57600/60000 (96%)]	Loss: 0.278213
#
# Train set: Average loss: 0.1629, Accuracy: 57297/60000 (95.5%)
#
#
# Test set: Average loss: 0.1560, Accuracy: 9533/10000 (95.330%)
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.179951
# Train Epoch: 6 [6400/60000 (11%)]	Loss: 0.212223
# Train Epoch: 6 [12800/60000 (21%)]	Loss: 0.166855
# Train Epoch: 6 [19200/60000 (32%)]	Loss: 0.199680
# Train Epoch: 6 [25600/60000 (43%)]	Loss: 0.198407
# Train Epoch: 6 [32000/60000 (53%)]	Loss: 0.209343
# Train Epoch: 6 [38400/60000 (64%)]	Loss: 0.087471
# Train Epoch: 6 [44800/60000 (75%)]	Loss: 0.035722
# Train Epoch: 6 [51200/60000 (85%)]	Loss: 0.446673
# Train Epoch: 6 [57600/60000 (96%)]	Loss: 0.104023
#
# Train set: Average loss: 0.0784, Accuracy: 57446/60000 (95.7%)
#
#
# Test set: Average loss: 0.1716, Accuracy: 9454/10000 (94.540%)
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.378229
# Train Epoch: 7 [6400/60000 (11%)]	Loss: 0.109099
# Train Epoch: 7 [12800/60000 (21%)]	Loss: 0.063635
# Train Epoch: 7 [19200/60000 (32%)]	Loss: 0.101438
# Train Epoch: 7 [25600/60000 (43%)]	Loss: 0.076959
# Train Epoch: 7 [32000/60000 (53%)]	Loss: 0.239343
# Train Epoch: 7 [38400/60000 (64%)]	Loss: 0.165861
# Train Epoch: 7 [44800/60000 (75%)]	Loss: 0.112993
# Train Epoch: 7 [51200/60000 (85%)]	Loss: 0.148418
# Train Epoch: 7 [57600/60000 (96%)]	Loss: 0.144410
#
# Train set: Average loss: 0.1012, Accuracy: 57586/60000 (96.0%)
#
#
# Test set: Average loss: 0.1531, Accuracy: 9545/10000 (95.450%)
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.230810
# Train Epoch: 8 [6400/60000 (11%)]	Loss: 0.143374
# Train Epoch: 8 [12800/60000 (21%)]	Loss: 0.180661
# Train Epoch: 8 [19200/60000 (32%)]	Loss: 0.140479
# Train Epoch: 8 [25600/60000 (43%)]	Loss: 0.083698
# Train Epoch: 8 [32000/60000 (53%)]	Loss: 0.117479
# Train Epoch: 8 [38400/60000 (64%)]	Loss: 0.066835
# Train Epoch: 8 [44800/60000 (75%)]	Loss: 0.115481
# Train Epoch: 8 [51200/60000 (85%)]	Loss: 0.118467
# Train Epoch: 8 [57600/60000 (96%)]	Loss: 0.203978
#
# Train set: Average loss: 0.0883, Accuracy: 57669/60000 (96.1%)
#
#
# Test set: Average loss: 0.1504, Accuracy: 9548/10000 (95.480%)
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.193045
# Train Epoch: 9 [6400/60000 (11%)]	Loss: 0.047099
# Train Epoch: 9 [12800/60000 (21%)]	Loss: 0.050104
# Train Epoch: 9 [19200/60000 (32%)]	Loss: 0.129285
# Train Epoch: 9 [25600/60000 (43%)]	Loss: 0.064773
# Train Epoch: 9 [32000/60000 (53%)]	Loss: 0.145636
# Train Epoch: 9 [38400/60000 (64%)]	Loss: 0.164183
# Train Epoch: 9 [44800/60000 (75%)]	Loss: 0.065934
# Train Epoch: 9 [51200/60000 (85%)]	Loss: 0.035281
# Train Epoch: 9 [57600/60000 (96%)]	Loss: 0.047194
#
# Train set: Average loss: 0.2506, Accuracy: 57719/60000 (96.2%)
#
#
# Test set: Average loss: 0.1488, Accuracy: 9559/10000 (95.590%)
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 0.096729
# Train Epoch: 10 [6400/60000 (11%)]	Loss: 0.117661
# Train Epoch: 10 [12800/60000 (21%)]	Loss: 0.039468
# Train Epoch: 10 [19200/60000 (32%)]	Loss: 0.057270
# Train Epoch: 10 [25600/60000 (43%)]	Loss: 0.065268
# Train Epoch: 10 [32000/60000 (53%)]	Loss: 0.166277
# Train Epoch: 10 [38400/60000 (64%)]	Loss: 0.199601
# Train Epoch: 10 [44800/60000 (75%)]	Loss: 0.192641
# Train Epoch: 10 [51200/60000 (85%)]	Loss: 0.127083
# Train Epoch: 10 [57600/60000 (96%)]	Loss: 0.128683
#
# Train set: Average loss: 0.1649, Accuracy: 57882/60000 (96.5%)
#
#
# Test set: Average loss: 0.1454, Accuracy: 9562/10000 (95.620%)
#
# Training is finished.

# %% [markdown]
# After training, you should see test accuracies of > **94%** - By they way, here we report test accuracy, the last exercises reported test error. Accuracy is simply (1 - error). Both metrics are commonly reported, there is no clear preference in literature for one or the other.

# %% [markdown]
# Now, can you do some parameter tuning to boost the test accuracy to > **97%**?

# %%
#########################################################################
#TODO: modify the parameters below to see which setting that you can get to 97%
#########################################################################
nLayer = 5
nHidden = 128
act_fn = nn.ReLU()

# reinitialize the mlp, so we can play with parameters right here
mlp = MLP(nInput, nOutput, nLayer, nHidden, act_fn)
optimizer = optim.Adam(mlp.parameters())

epochs = 10
for epoch in range(1, epochs + 1):
    train(mlp, dl_train, optimizer, epoch, log_interval=100)
    test(mlp, dl_test)

print ('Training is finished.')
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.312551
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 0.351221
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.332639
# Train Epoch: 1 [19200/60000 (32%)]	Loss: 0.274193
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.237370
# Train Epoch: 1 [32000/60000 (53%)]	Loss: 0.210954
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.071218
# Train Epoch: 1 [44800/60000 (75%)]	Loss: 0.140083
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.208242
# Train Epoch: 1 [57600/60000 (96%)]	Loss: 0.150691
#
# Train set: Average loss: 0.1749, Accuracy: 54048/60000 (90.1%)
#
#
# Test set: Average loss: 0.1388, Accuracy: 9582/10000 (95.820%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.061938
# Train Epoch: 2 [6400/60000 (11%)]	Loss: 0.150372
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.133847
# Train Epoch: 2 [19200/60000 (32%)]	Loss: 0.165656
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.025115
# Train Epoch: 2 [32000/60000 (53%)]	Loss: 0.049234
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 0.114224
# Train Epoch: 2 [44800/60000 (75%)]	Loss: 0.292762
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.041445
# Train Epoch: 2 [57600/60000 (96%)]	Loss: 0.084676
#
# Train set: Average loss: 0.0981, Accuracy: 57703/60000 (96.2%)
#
#
# Test set: Average loss: 0.1061, Accuracy: 9683/10000 (96.830%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.033620
# Train Epoch: 3 [6400/60000 (11%)]	Loss: 0.046704
# Train Epoch: 3 [12800/60000 (21%)]	Loss: 0.095266
# Train Epoch: 3 [19200/60000 (32%)]	Loss: 0.023956
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.037758
# Train Epoch: 3 [32000/60000 (53%)]	Loss: 0.106105
# Train Epoch: 3 [38400/60000 (64%)]	Loss: 0.126265
# Train Epoch: 3 [44800/60000 (75%)]	Loss: 0.075799
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.052120
# Train Epoch: 3 [57600/60000 (96%)]	Loss: 0.023237
#
# Train set: Average loss: 0.0833, Accuracy: 58331/60000 (97.2%)
#
#
# Test set: Average loss: 0.1025, Accuracy: 9707/10000 (97.070%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.057284
# Train Epoch: 4 [6400/60000 (11%)]	Loss: 0.070617
# Train Epoch: 4 [12800/60000 (21%)]	Loss: 0.051148
# Train Epoch: 4 [19200/60000 (32%)]	Loss: 0.055699
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.136507
# Train Epoch: 4 [32000/60000 (53%)]	Loss: 0.022692
# Train Epoch: 4 [38400/60000 (64%)]	Loss: 0.007787
# Train Epoch: 4 [44800/60000 (75%)]	Loss: 0.088128
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.025208
# Train Epoch: 4 [57600/60000 (96%)]	Loss: 0.014673
#
# Train set: Average loss: 0.0392, Accuracy: 58659/60000 (97.8%)
#
#
# Test set: Average loss: 0.0906, Accuracy: 9728/10000 (97.280%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.142363
# Train Epoch: 5 [6400/60000 (11%)]	Loss: 0.017905
# Train Epoch: 5 [12800/60000 (21%)]	Loss: 0.020814
# Train Epoch: 5 [19200/60000 (32%)]	Loss: 0.123468
# Train Epoch: 5 [25600/60000 (43%)]	Loss: 0.052553
# Train Epoch: 5 [32000/60000 (53%)]	Loss: 0.039554
# Train Epoch: 5 [38400/60000 (64%)]	Loss: 0.012867
# Train Epoch: 5 [44800/60000 (75%)]	Loss: 0.021724
# Train Epoch: 5 [51200/60000 (85%)]	Loss: 0.058384
# Train Epoch: 5 [57600/60000 (96%)]	Loss: 0.010108
#
# Train set: Average loss: 0.0230, Accuracy: 58891/60000 (98.2%)
#
#
# Test set: Average loss: 0.0849, Accuracy: 9760/10000 (97.600%)
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.022925
# Train Epoch: 6 [6400/60000 (11%)]	Loss: 0.012101
# Train Epoch: 6 [12800/60000 (21%)]	Loss: 0.011610
# Train Epoch: 6 [19200/60000 (32%)]	Loss: 0.003880
# Train Epoch: 6 [25600/60000 (43%)]	Loss: 0.029287
# Train Epoch: 6 [32000/60000 (53%)]	Loss: 0.122718
# Train Epoch: 6 [38400/60000 (64%)]	Loss: 0.161999
# Train Epoch: 6 [44800/60000 (75%)]	Loss: 0.117115
# Train Epoch: 6 [51200/60000 (85%)]	Loss: 0.009792
# Train Epoch: 6 [57600/60000 (96%)]	Loss: 0.099490
#
# Train set: Average loss: 0.1951, Accuracy: 59012/60000 (98.4%)
#
#
# Test set: Average loss: 0.0818, Accuracy: 9773/10000 (97.730%)
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.009362
# Train Epoch: 7 [6400/60000 (11%)]	Loss: 0.035543
# Train Epoch: 7 [12800/60000 (21%)]	Loss: 0.161781
# Train Epoch: 7 [19200/60000 (32%)]	Loss: 0.078635
# Train Epoch: 7 [25600/60000 (43%)]	Loss: 0.018625
# Train Epoch: 7 [32000/60000 (53%)]	Loss: 0.069154
# Train Epoch: 7 [38400/60000 (64%)]	Loss: 0.132205
# Train Epoch: 7 [44800/60000 (75%)]	Loss: 0.094628
# Train Epoch: 7 [51200/60000 (85%)]	Loss: 0.143354
# Train Epoch: 7 [57600/60000 (96%)]	Loss: 0.000922
#
# Train set: Average loss: 0.1109, Accuracy: 59143/60000 (98.6%)
#
#
# Test set: Average loss: 0.0926, Accuracy: 9740/10000 (97.400%)
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.009741
# Train Epoch: 8 [6400/60000 (11%)]	Loss: 0.109302
# Train Epoch: 8 [12800/60000 (21%)]	Loss: 0.010148
# Train Epoch: 8 [19200/60000 (32%)]	Loss: 0.005936
# Train Epoch: 8 [25600/60000 (43%)]	Loss: 0.115994
# Train Epoch: 8 [32000/60000 (53%)]	Loss: 0.040541
# Train Epoch: 8 [38400/60000 (64%)]	Loss: 0.021795
# Train Epoch: 8 [44800/60000 (75%)]	Loss: 0.039708
# Train Epoch: 8 [51200/60000 (85%)]	Loss: 0.056635
# Train Epoch: 8 [57600/60000 (96%)]	Loss: 0.012623
#
# Train set: Average loss: 0.0445, Accuracy: 59271/60000 (98.8%)
#
#
# Test set: Average loss: 0.0846, Accuracy: 9780/10000 (97.800%)
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.004794
# Train Epoch: 9 [6400/60000 (11%)]	Loss: 0.105812
# Train Epoch: 9 [12800/60000 (21%)]	Loss: 0.005307
# Train Epoch: 9 [19200/60000 (32%)]	Loss: 0.000488
# Train Epoch: 9 [25600/60000 (43%)]	Loss: 0.022353
# Train Epoch: 9 [32000/60000 (53%)]	Loss: 0.044882
# Train Epoch: 9 [38400/60000 (64%)]	Loss: 0.004584
# Train Epoch: 9 [44800/60000 (75%)]	Loss: 0.020810
# Train Epoch: 9 [51200/60000 (85%)]	Loss: 0.001405
# Train Epoch: 9 [57600/60000 (96%)]	Loss: 0.002872
#
# Train set: Average loss: 0.0016, Accuracy: 59294/60000 (98.8%)
#
#
# Test set: Average loss: 0.0871, Accuracy: 9762/10000 (97.620%)
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 0.001096
# Train Epoch: 10 [6400/60000 (11%)]	Loss: 0.028273
# Train Epoch: 10 [12800/60000 (21%)]	Loss: 0.000961
# Train Epoch: 10 [19200/60000 (32%)]	Loss: 0.000893
# Train Epoch: 10 [25600/60000 (43%)]	Loss: 0.000769
# Train Epoch: 10 [32000/60000 (53%)]	Loss: 0.018993
# Train Epoch: 10 [38400/60000 (64%)]	Loss: 0.020256
# Train Epoch: 10 [44800/60000 (75%)]	Loss: 0.004787
# Train Epoch: 10 [51200/60000 (85%)]	Loss: 0.030524
# Train Epoch: 10 [57600/60000 (96%)]	Loss: 0.045937
#
# Train set: Average loss: 0.0024, Accuracy: 59384/60000 (99.0%)
#
#
# Test set: Average loss: 0.0924, Accuracy: 9751/10000 (97.510%)
#
# Training is finished.

# %% [markdown]
# Before you move on to the next exercise, you can further play with the other parameters (learning rate, epochs, a different optimizer, etc.) to get a feeling what can improve or hamper performance.

# %% [markdown]
# ## CNN
# Alright, we matched our prior performance. Let's surpass it! You will soon see the power of CNN by building a small one yourself. The structure should be as follows
#
# | CNN Architecture                             	|
# |----------------------------------------------	|
# | Conv: $C_{in}=1, C_{out}=32, K=3, S=1, P=0$  	|
# | ReLU                                         	|
# | Conv: $C_{in}=32, C_{out}=64, K=3, S=1, P=0$ 	|
# | ReLU                                         	|
# | MaxPool2d: $K=2, S=2, P=0$                   	|
# | Dropout: $p=0.25$                            	|
# | Linear: $C_{in}=9216, C_{out}=128$           	|
# | ReLU                                         	|
# | Dropout: $p=0.5$                             	|
# | Linear: $C_{in}=128, C_{out}=10$             	|
#
# The layers you will need are:
#
# `nn.Conv2d,  nn.Linear,  nn.Dropout, nn.MaxPool2d, nn.Flatten`
#
# For layers without parameters you can alternatively use function in the forward pass:
#
# `F.max_pool2d, torch.flatten`

# %%
#########################################################################
# TODO: Implement the __init__ and forward method of the CNN class. 
# Hint: do not forget to flatten the appropriate dimension after the convolutional blocks. 
# A linear layers expect input of the size (B, H) with batch size B and feature size H
#########################################################################

class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()

        self.model = nn.Sequential(
            nn.Conv2d(1, 16, 3, padding=1),
            nn.ReLU(),
            nn.Conv2d(16, 32, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(32, 64, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Flatten(),
            nn.Linear(64*7*7, 10)
        )

    def forward(self, x):
        return self.model(x)

# %%
# Let's test if the forward pass works
# this should print torch.Size([1, 10])
t = torch.randn(1,1,28,28)
cnn = CNN()
cnn(t).shape
# Out:
# torch.Size([1, 10])

# %% [markdown]
# Alright, let's train!

# %%
optimizer = optim.Adam(cnn.parameters())

# %%
epochs = 5
for epoch in range(1, epochs + 1):
    train(cnn, dl_train, optimizer, epoch, log_interval=100)
    test(cnn, dl_test)
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.312290
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 0.141971
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.098171
# Train Epoch: 1 [19200/60000 (32%)]	Loss: 0.068460
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.146582
# Train Epoch: 1 [32000/60000 (53%)]	Loss: 0.066038
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.047365
# Train Epoch: 1 [44800/60000 (75%)]	Loss: 0.110956
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.081932
# Train Epoch: 1 [57600/60000 (96%)]	Loss: 0.094388
#
# Train set: Average loss: 0.0081, Accuracy: 57449/60000 (95.7%)
#
#
# Test set: Average loss: 0.0350, Accuracy: 9882/10000 (98.820%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.008294
# Train Epoch: 2 [6400/60000 (11%)]	Loss: 0.011553
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.033892
# Train Epoch: 2 [19200/60000 (32%)]	Loss: 0.084882
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.048515
# Train Epoch: 2 [32000/60000 (53%)]	Loss: 0.046409
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 0.071670
# Train Epoch: 2 [44800/60000 (75%)]	Loss: 0.015616
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.007799
# Train Epoch: 2 [57600/60000 (96%)]	Loss: 0.005239
#
# Train set: Average loss: 0.0087, Accuracy: 59228/60000 (98.7%)
#
#
# Test set: Average loss: 0.0320, Accuracy: 9902/10000 (99.020%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.012832
# Train Epoch: 3 [6400/60000 (11%)]	Loss: 0.035464
# Train Epoch: 3 [12800/60000 (21%)]	Loss: 0.012907
# Train Epoch: 3 [19200/60000 (32%)]	Loss: 0.006997
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.024213
# Train Epoch: 3 [32000/60000 (53%)]	Loss: 0.001768
# Train Epoch: 3 [38400/60000 (64%)]	Loss: 0.003943
# Train Epoch: 3 [44800/60000 (75%)]	Loss: 0.002940
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.015240
# Train Epoch: 3 [57600/60000 (96%)]	Loss: 0.028778
#
# Train set: Average loss: 0.0009, Accuracy: 59415/60000 (99.0%)
#
#
# Test set: Average loss: 0.0329, Accuracy: 9900/10000 (99.000%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.009942
# Train Epoch: 4 [6400/60000 (11%)]	Loss: 0.030448
# Train Epoch: 4 [12800/60000 (21%)]	Loss: 0.003266
# Train Epoch: 4 [19200/60000 (32%)]	Loss: 0.049603
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.030976
# Train Epoch: 4 [32000/60000 (53%)]	Loss: 0.026752
# Train Epoch: 4 [38400/60000 (64%)]	Loss: 0.002224
# Train Epoch: 4 [44800/60000 (75%)]	Loss: 0.017308
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.007898
# Train Epoch: 4 [57600/60000 (96%)]	Loss: 0.020833
#
# Train set: Average loss: 0.0018, Accuracy: 59582/60000 (99.3%)
#
#
# Test set: Average loss: 0.0302, Accuracy: 9912/10000 (99.120%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.002658
# Train Epoch: 5 [6400/60000 (11%)]	Loss: 0.001206
# Train Epoch: 5 [12800/60000 (21%)]	Loss: 0.003883
# Train Epoch: 5 [19200/60000 (32%)]	Loss: 0.013055
# Train Epoch: 5 [25600/60000 (43%)]	Loss: 0.005180
# Train Epoch: 5 [32000/60000 (53%)]	Loss: 0.001518
# Train Epoch: 5 [38400/60000 (64%)]	Loss: 0.002590
# Train Epoch: 5 [44800/60000 (75%)]	Loss: 0.000086
# Train Epoch: 5 [51200/60000 (85%)]	Loss: 0.007242
# Train Epoch: 5 [57600/60000 (96%)]	Loss: 0.013487
#
# Train set: Average loss: 0.0319, Accuracy: 59660/60000 (99.4%)
#
#
# Test set: Average loss: 0.0299, Accuracy: 9908/10000 (99.080%)

# %% [markdown]
# This will probably take a bit longer to train, as a convolutional network is not very efficient on a CPU. The current settings should get you around **99%** accuracy. Nice!
# Again, you should try different hyperparameters and see how far you can push the performance.

# %% [markdown]
# ### Inline Question
#
# If your model weight is randomly initalized, and no training is done as above. What accuracy do you think the model will get for a 10-class classification task in theory?
#
# **Your answer**:

# %% [markdown]
# Over a large enough model the random weights should make for an evenly distributed probability for each answer. There are ten answers so $p = \frac{1}{10}$ each. So we expect also an accuracy of 10%.

# %% [markdown]
# ## Training on CIFAR10
#
# Now we are going to move to something more challenging - CIFAR10. We can reuse most of the code above. Thankfully, CIFAR is also a popular dataset, so we can again make use of a PyTorch convience function.

# %%
ds_train = datasets.CIFAR10(root='./data', train=True, download=True)
# Out:
# Files already downloaded and verified

# %% [markdown]
# This dataset is not normalized yet, so we need to calculate the normalization constants.

# %%
ims_train = torch.tensor(ds_train.data)
ims_train = ims_train.float() / 255.

# %%
ims_train.std((0,1,2))
# Out:
# tensor([0.2470, 0.2435, 0.2616])

# %%
#########################################################################
# TODO: calculate the mean and std of CIFAR
# hint: We want the mean and std of the channel dimension, these should
# be 3 dimensional
#########################################################################
mu = torch.mean(ims_train)
std = torch.std(ims_train)

# %%
torch.mean(ims_train, dim=(0,1,2))
# Out:
# tensor([0.4914, 0.4822, 0.4465])

# %% [markdown]
# For CIFAR we want to make use of data augmentation to improve generalization. You will find all data augmentations data are included in torchvision here:
#
# https://pytorch.org/docs/stable/torchvision/transforms.html

# %%
BATCH_SIZE = 128
NUM_WORKERS = 4 # if you encounter some unexpected errors in data loading, try setting `NUM_WORKERS = 0`
#########################################################################
# TODO: Implement the proper transforms for the training and test dataloaders. 
# Then build train and test dataloaders with batch size 128 and 4 workers
#
# Train: 
# - Apply a random crop with size 32 on a padded version of the image with P=4
# - Flip the image horizontally with a probability of 40 %
# - Transform to a Tensor
# - Normalize with the constants calculated above
# Test: 
# - Transform to a Tensor
# - Normalize with the constants calculated above
#########################################################################
transform_train = transforms.Compose([
    transforms.Pad(4),
    transforms.RandomCrop(32),
    transforms.RandomHorizontalFlip(p=0.4),
    transforms.ToTensor(),
    transforms.Normalize(mu, std)
])
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mu, std)
])

ds_train = datasets.CIFAR10('./data', train=True, download=True, transform=transform_train)
ds_test = datasets.CIFAR10('./data', train=False, download=True, transform=transform_test)

dl_train = DataLoader(ds_train, batch_size=128, shuffle=True, num_workers=4)
dl_test = DataLoader(ds_test, batch_size=128, shuffle=True, num_workers=4)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# Setting up the  optimizer, this time we use SGD. The scheduler adapts the learning rate during traing (you can ignore it)

# %%
cnn = CNN()
optimizer = optim.SGD(cnn.parameters(), lr=0.1, momentum=0.9, weight_decay=5e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)

# %%
epochs = 5
for epoch in range(1, epochs + 1):
    train(cnn, dl_train, optimizer, epoch, log_interval=100)
    test(cnn, dl_test)    
    scheduler.step()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/ben/University/cv/lab03/code/image_classification.ipynb Cell 56 line 3
#       <a href='vscode-notebook-cell:/Users/ben/University/cv/lab03/code/image_classification.ipynb#Y106sZmlsZQ%3D%3D?line=0'>1</a> epochs = 5
#       <a href='vscode-notebook-cell:/Users/ben/University/cv/lab03/code/image_classification.ipynb#Y106sZmlsZQ%3D%3D?line=1'>2</a> for epoch in range(1, epochs + 1):
# ----> <a href='vscode-notebook-cell:/Users/ben/University/cv/lab03/code/image_classification.ipynb#Y106sZmlsZQ%3D%3D?line=2'>3</a>     train(cnn, dl_train, optimizer, epoch, log_interval=100)
#       <a href='vscode-notebook-cell:/Users/ben/University/cv/lab03/code/image_classification.ipynb#Y106sZmlsZQ%3D%3D?line=3'>4</a>     test(cnn, dl_test)
#       <a href='vscode-notebook-cell:/Users/ben/University/cv/lab03/code/image_classification.ipynb#Y106sZmlsZQ%3D%3D?line=4'>5</a>     scheduler.step()
#
# /Users/ben/University/cv/lab03/code/image_classification.ipynb Cell 56 line 1
#      <a href='vscode-notebook-cell:/Users/ben/University/cv/lab03/code/image_classification.ipynb#Y106sZmlsZQ%3D%3D?line=12'>13</a> optimizer.zero_grad()
#      <a href='vscode-notebook-cell:/Users/ben/University/cv/lab03/code/image_classification.ipynb#Y106sZmlsZQ%3D%3D?line=14'>15</a> ##### implement this part #####
#      <a href='vscode-notebook-cell:/Users/ben/University/cv/lab03/code/image_classification.ipynb#Y106sZmlsZQ%3D%3D?line=15'>16</a>
#      <a href='vscode-notebook-cell:/Users/ben/University/cv/lab03/code/image_classification.ipynb#Y106sZmlsZQ%3D%3D?line=16'>17</a> # pass through the model
# ---> <a href='vscode-notebook-cell:/Users/ben/University/cv/lab03/code/image_classification.ipynb#Y106sZmlsZQ%3D%3D?line=17'>18</a> output = model(data)
#      <a href='vscode-notebook-cell:/Users/ben/University/cv/lab03/code/image_classification.ipynb#Y106sZmlsZQ%3D%3D?line=19'>20</a> # calculate the loss
#      <a href='vscode-notebook-cell:/Users/ben/University/cv/lab03/code/image_classification.ipynb#Y106sZmlsZQ%3D%3D?line=20'>21</a> loss = F.cross_entropy(output, target)
#
# File ~/University/cv/lab03/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/University/cv/lab03/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# /Users/ben/University/cv/lab03/code/image_classification.ipynb Cell 56 line 2
#      <a href='vscode-notebook-cell:/Users/ben/University/cv/lab03/code/image_classification.ipynb#Y106sZmlsZQ%3D%3D?line=23'>24</a> def forward(self, x):
# ---> <a href='vscode-notebook-cell:/Users/ben/University/cv/lab03/code/image_classification.ipynb#Y106sZmlsZQ%3D%3D?line=24'>25</a>     return self.model(x)
#
# File ~/University/cv/lab03/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/University/cv/lab03/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/University/cv/lab03/.venv/lib/python3.11/site-packages/torch/nn/modules/container.py:215, in Sequential.forward(self, input)
#     213 def forward(self, input):
#     214     for module in self:
# --> 215         input = module(input)
#     216     return input
#
# File ~/University/cv/lab03/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/University/cv/lab03/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/University/cv/lab03/.venv/lib/python3.11/site-packages/torch/nn/modules/conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/University/cv/lab03/.venv/lib/python3.11/site-packages/torch/nn/modules/conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# RuntimeError: Given groups=1, weight of size [16, 1, 3, 3], expected input[128, 3, 32, 32] to have 1 channels, but got 3 channels instead

# %% [markdown]
# This will not work. You should see the following error message
#
# ```
# Given groups=1, weight of size [32, 1, 3, 3], expected input[128, 3, 32, 32] to have 1 channels, but got 3 channels instead
# ```
#
# This error is telling us that something is not right in the definition of our model. Copy the CNN class from above and make changes, so the training works.

# %%
#########################################################################
# TODO: Adapt the definition from the CNN class above to work on CIFAR.
# You can copy and run the following prompt for evaluation:
# CNN()(torch.randn(1,3,32,32)).shape
# It should print 'torch.Size([1, 10])'
# Hint: You need to change 2 things. 
#########################################################################

class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()

        self.model = nn.Sequential(
            nn.Conv2d(3, 16, 3, padding=1),
            nn.ReLU(),
            nn.Conv2d(16, 32, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(32, 64, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Flatten(),
            nn.Linear(64*8*8, 10)
        )

    def forward(self, x):
        return self.model(x)
    
CNN()(torch.randn(1,3,32,32)).shape
# Out:
# torch.Size([1, 10])

# %% [markdown]
# Let's try again

# %%
cnn = CNN()
optimizer = optim.SGD(cnn.parameters(), lr=0.1, momentum=0.9, weight_decay=5e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)

epochs = 10
for epoch in range(1, epochs + 1):
    train(cnn, dl_train, optimizer, epoch, log_interval=100)
    test(cnn, dl_test)    
    scheduler.step()
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.304354
# Train Epoch: 1 [12800/50000 (26%)]	Loss: 1.856973
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 1.848577
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 1.681999
#
# Train set: Average loss: 1.7010, Accuracy: 16853/50000 (33.7%)
#
#
# Test set: Average loss: 1.7036, Accuracy: 3956/10000 (39.560%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.788703
# Train Epoch: 2 [12800/50000 (26%)]	Loss: 1.761922
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 1.777165
# Train Epoch: 2 [38400/50000 (77%)]	Loss: 1.576887
#
# Train set: Average loss: 1.5494, Accuracy: 21264/50000 (42.5%)
#
#
# Test set: Average loss: 1.4656, Accuracy: 4721/10000 (47.210%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 1.627363
# Train Epoch: 3 [12800/50000 (26%)]	Loss: 1.696175
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 1.576396
# Train Epoch: 3 [38400/50000 (77%)]	Loss: 1.485131
#
# Train set: Average loss: 1.6356, Accuracy: 22578/50000 (45.2%)
#
#
# Test set: Average loss: 1.4566, Accuracy: 4824/10000 (48.240%)
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 1.492187
# Train Epoch: 4 [12800/50000 (26%)]	Loss: 1.627595
# Train Epoch: 4 [25600/50000 (51%)]	Loss: 1.537771
# Train Epoch: 4 [38400/50000 (77%)]	Loss: 1.629781
#
# Train set: Average loss: 1.4070, Accuracy: 23783/50000 (47.6%)
#
#
# Test set: Average loss: 1.3340, Accuracy: 5306/10000 (53.060%)
#
# Train Epoch: 5 [0/50000 (0%)]	Loss: 1.344594
# Train Epoch: 5 [12800/50000 (26%)]	Loss: 1.457602
# Train Epoch: 5 [25600/50000 (51%)]	Loss: 1.462242
# Train Epoch: 5 [38400/50000 (77%)]	Loss: 1.181843
#
# Train set: Average loss: 1.1864, Accuracy: 25053/50000 (50.1%)
#
#
# Test set: Average loss: 1.2308, Accuracy: 5676/10000 (56.760%)
#
# Train Epoch: 6 [0/50000 (0%)]	Loss: 1.331592
# Train Epoch: 6 [12800/50000 (26%)]	Loss: 1.402346
# Train Epoch: 6 [25600/50000 (51%)]	Loss: 1.260371
# Train Epoch: 6 [38400/50000 (77%)]	Loss: 1.363741
#
# Train set: Average loss: 1.2694, Accuracy: 25440/50000 (50.9%)
#
#
# Test set: Average loss: 1.2888, Accuracy: 5438/10000 (54.380%)
#
# Train Epoch: 7 [0/50000 (0%)]	Loss: 1.237909
# Train Epoch: 7 [12800/50000 (26%)]	Loss: 1.430963
# Train Epoch: 7 [25600/50000 (51%)]	Loss: 1.465176
# Train Epoch: 7 [38400/50000 (77%)]	Loss: 1.434425
#
# Train set: Average loss: 1.5116, Accuracy: 25958/50000 (51.9%)
#
#
# Test set: Average loss: 1.1779, Accuracy: 5773/10000 (57.730%)
#
# Train Epoch: 8 [0/50000 (0%)]	Loss: 1.354374
# Train Epoch: 8 [12800/50000 (26%)]	Loss: 1.260463
# Train Epoch: 8 [25600/50000 (51%)]	Loss: 1.324015
# Train Epoch: 8 [38400/50000 (77%)]	Loss: 1.350979
#
# Train set: Average loss: 1.3196, Accuracy: 25954/50000 (51.9%)
#
#
# Test set: Average loss: 1.2141, Accuracy: 5733/10000 (57.330%)
#
# Train Epoch: 9 [0/50000 (0%)]	Loss: 1.315001
# Train Epoch: 9 [12800/50000 (26%)]	Loss: 1.480990
# Train Epoch: 9 [25600/50000 (51%)]	Loss: 1.476707
# Train Epoch: 9 [38400/50000 (77%)]	Loss: 1.402033
#
# Train set: Average loss: 1.5099, Accuracy: 26641/50000 (53.3%)
#
#
# Test set: Average loss: 1.1537, Accuracy: 5908/10000 (59.080%)
#
# Train Epoch: 10 [0/50000 (0%)]	Loss: 1.153428
# Train Epoch: 10 [12800/50000 (26%)]	Loss: 1.194947
# Train Epoch: 10 [25600/50000 (51%)]	Loss: 1.222696
# Train Epoch: 10 [38400/50000 (77%)]	Loss: 1.214800
#
# Train set: Average loss: 1.4525, Accuracy: 26724/50000 (53.4%)
#
#
# Test set: Average loss: 1.2466, Accuracy: 5578/10000 (55.780%)

# %% [markdown]
# This should give 40 - 50 % - and if you are not already on Colab it will give you a stressed out laptop. The performance is a lot better than random, but we can definitely do better.

# %% [markdown]
# ### Have fun with GPUs
# You can already call it a day until this point because we won't grade the rest of the excecise. You can have more fun with the rest :)

# %% [markdown]
# If you didn't already, move to colab. To use a GPU, follow on the collaboratory menu tabs, "Runtime" => "Change runtime type" and set it to GPU. Then run the same training loop but now on GPU.
#
# It as easy as:

# %%
# running on m1 macbook
# device = 'cuda' if torch.cuda.is_available() else 'mps'
# if device == 'cuda': torch.backends.cudnn.benchmark = True # additional speed up

device = torch.device("mps")

cnn = CNN()
optimizer = optim.SGD(cnn.parameters(), lr=0.1, momentum=0.9, weight_decay=5e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)
cnn = cnn.to(device)

epochs = 10
for epoch in range(1, epochs + 1):
    train(cnn, dl_train, optimizer, epoch, log_interval=100, device=device)
    test(cnn, dl_test, device=device)    
    scheduler.step()
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.299230
# Train Epoch: 1 [12800/50000 (26%)]	Loss: 2.079957
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 1.984023
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 1.758533
#
# Train set: Average loss: 1.6729, Accuracy: 14468/50000 (28.9%)
#
#
# Test set: Average loss: 1.7756, Accuracy: 3711/10000 (37.110%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.766825
# Train Epoch: 2 [12800/50000 (26%)]	Loss: 1.605015
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 1.680794
# Train Epoch: 2 [38400/50000 (77%)]	Loss: 1.806053
#
# Train set: Average loss: 1.7251, Accuracy: 18325/50000 (36.6%)
#
#
# Test set: Average loss: 1.7470, Accuracy: 3572/10000 (35.720%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 1.854237
# Train Epoch: 3 [12800/50000 (26%)]	Loss: 1.673998
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 1.618656
# Train Epoch: 3 [38400/50000 (77%)]	Loss: 1.736861
#
# Train set: Average loss: 1.8073, Accuracy: 19601/50000 (39.2%)
#
#
# Test set: Average loss: 1.5470, Accuracy: 4538/10000 (45.380%)
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 1.833520
# Train Epoch: 4 [12800/50000 (26%)]	Loss: 1.580592
# Train Epoch: 4 [25600/50000 (51%)]	Loss: 1.734840
# Train Epoch: 4 [38400/50000 (77%)]	Loss: 1.683386
#
# Train set: Average loss: 1.7080, Accuracy: 20845/50000 (41.7%)
#
#
# Test set: Average loss: 1.4520, Accuracy: 4767/10000 (47.670%)
#
# Train Epoch: 5 [0/50000 (0%)]	Loss: 1.678083
# Train Epoch: 5 [12800/50000 (26%)]	Loss: 1.812921
# Train Epoch: 5 [25600/50000 (51%)]	Loss: 1.517448
# Train Epoch: 5 [38400/50000 (77%)]	Loss: 1.656976
#
# Train set: Average loss: 1.3665, Accuracy: 21508/50000 (43.0%)
#
#
# Test set: Average loss: 1.3871, Accuracy: 5127/10000 (51.270%)
#
# Train Epoch: 6 [0/50000 (0%)]	Loss: 1.459991
# Train Epoch: 6 [12800/50000 (26%)]	Loss: 1.591921
# Train Epoch: 6 [25600/50000 (51%)]	Loss: 1.574742
# Train Epoch: 6 [38400/50000 (77%)]	Loss: 1.446335
#
# Train set: Average loss: 1.6101, Accuracy: 22331/50000 (44.7%)
#
#
# Test set: Average loss: 1.4267, Accuracy: 5051/10000 (50.510%)
#
# Train Epoch: 7 [0/50000 (0%)]	Loss: 1.503917
# Train Epoch: 7 [12800/50000 (26%)]	Loss: 1.515575
# Train Epoch: 7 [25600/50000 (51%)]	Loss: 1.587736
# Train Epoch: 7 [38400/50000 (77%)]	Loss: 1.628628
#
# Train set: Average loss: 1.3428, Accuracy: 22640/50000 (45.3%)
#
#
# Test set: Average loss: 1.3511, Accuracy: 5148/10000 (51.480%)
#
# Train Epoch: 8 [0/50000 (0%)]	Loss: 1.376003
# Train Epoch: 8 [12800/50000 (26%)]	Loss: 1.538564
# Train Epoch: 8 [25600/50000 (51%)]	Loss: 1.503300
# Train Epoch: 8 [38400/50000 (77%)]	Loss: 1.675055
#
# Train set: Average loss: 1.4337, Accuracy: 23339/50000 (46.7%)
#
#
# Test set: Average loss: 1.4328, Accuracy: 4977/10000 (49.770%)
#
# Train Epoch: 9 [0/50000 (0%)]	Loss: 1.541474
# Train Epoch: 9 [12800/50000 (26%)]	Loss: 1.646585
# Train Epoch: 9 [25600/50000 (51%)]	Loss: 1.489307
# Train Epoch: 9 [38400/50000 (77%)]	Loss: 1.411558
#
# Train set: Average loss: 1.6434, Accuracy: 23674/50000 (47.3%)
#
#
# Test set: Average loss: 1.3066, Accuracy: 5436/10000 (54.360%)
#
# Train Epoch: 10 [0/50000 (0%)]	Loss: 1.618136
# Train Epoch: 10 [12800/50000 (26%)]	Loss: 1.506312
# Train Epoch: 10 [25600/50000 (51%)]	Loss: 1.523365
# Train Epoch: 10 [38400/50000 (77%)]	Loss: 1.460267
#
# Train set: Average loss: 1.4681, Accuracy: 23949/50000 (47.9%)
#
#
# Test set: Average loss: 1.3604, Accuracy: 5089/10000 (50.890%)

# %% [markdown]
# This should be way faster now. But the true advantage of the GPU is that we can use much bigger models now and still train them in a reasonable amount of time. PyTorch is again very handy. The torchvision library comes with varies state-of-the-art model architectures, some of which you have seen in the lecture.

# %%
from torchvision.models import resnet18

# %%
cnn = resnet18()
print(cnn)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %% [markdown]
# Looks scary! But the only thing you need to change to make it work on CIFAR is the last layer.
# Currently the last layer is:
# ```
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# ```
# out_features is the number of classes. This models are developed for Imagenet, a dataset with 1000 classes. So this part of the model you need to adapt. Additionally, you need to add a log-softmax layer again, as we us negative log-likelihood as the training criterion.

# %%
#########################################################################
# TODO: Adapt the Resnet to work on CIFAR
#########################################################################

cnn = resnet18()
cnn.conv1 = nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=3, bias=False)
cnn.fc = nn.Linear(512, out_features=10, bias=True)

print(cnn)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
# This should print 'torch.Size([16, 10])'
cnn(torch.randn(16,3,32,32)).shape
# Out:
# torch.Size([16, 10])

# %%
# device = 'cuda'
# if device == 'cuda': torch.backends.cudnn.benchmark = True # this gives us additional speed up

device = torch.device("mps")

optimizer = optim.SGD(cnn.parameters(), lr=0.1, momentum=0.9, weight_decay=5e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)
cnn = cnn.to(device)

epochs = 50
for epoch in range(1, epochs + 1):
    train(cnn, dl_train, optimizer, epoch, log_interval=100, device=device)
    test(cnn, dl_test, device=device)    
    scheduler.step()
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.568891
# Train Epoch: 1 [12800/50000 (26%)]	Loss: 2.291580
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 1.971486
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 1.899189
#
# Train set: Average loss: 1.5073, Accuracy: 15182/50000 (30.4%)
#
#
# Test set: Average loss: 1.6877, Accuracy: 4069/10000 (40.690%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.691331
# Train Epoch: 2 [12800/50000 (26%)]	Loss: 1.521978
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 1.589122
# Train Epoch: 2 [38400/50000 (77%)]	Loss: 1.427315
#
# Train set: Average loss: 1.3838, Accuracy: 22072/50000 (44.1%)
#
#
# Test set: Average loss: 1.3467, Accuracy: 5134/10000 (51.340%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 1.531760
# Train Epoch: 3 [12800/50000 (26%)]	Loss: 1.335726
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 1.215634
# Train Epoch: 3 [38400/50000 (77%)]	Loss: 1.364640
#
# Train set: Average loss: 1.1615, Accuracy: 25674/50000 (51.3%)
#
#
# Test set: Average loss: 1.2477, Accuracy: 5505/10000 (55.050%)
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 1.196678
# Train Epoch: 4 [12800/50000 (26%)]	Loss: 1.246325
# Train Epoch: 4 [25600/50000 (51%)]	Loss: 1.079487
# Train Epoch: 4 [38400/50000 (77%)]	Loss: 1.166912
#
# Train set: Average loss: 1.1069, Accuracy: 28755/50000 (57.5%)
#
#
# Test set: Average loss: 1.1109, Accuracy: 6135/10000 (61.350%)
#
# Train Epoch: 5 [0/50000 (0%)]	Loss: 1.099897
# Train Epoch: 5 [12800/50000 (26%)]	Loss: 0.983663
# Train Epoch: 5 [25600/50000 (51%)]	Loss: 0.927693
# Train Epoch: 5 [38400/50000 (77%)]	Loss: 1.025987
#
# Train set: Average loss: 1.0089, Accuracy: 31087/50000 (62.2%)
#
#
# Test set: Average loss: 1.0461, Accuracy: 6401/10000 (64.010%)
#
# Train Epoch: 6 [0/50000 (0%)]	Loss: 0.975452
# Train Epoch: 6 [12800/50000 (26%)]	Loss: 1.059869
# Train Epoch: 6 [25600/50000 (51%)]	Loss: 0.934126
# Train Epoch: 6 [38400/50000 (77%)]	Loss: 1.035116
#
# Train set: Average loss: 0.6905, Accuracy: 32446/50000 (64.9%)
#
#
# Test set: Average loss: 0.9999, Accuracy: 6549/10000 (65.490%)
#
# Train Epoch: 7 [0/50000 (0%)]	Loss: 1.030555
# Train Epoch: 7 [12800/50000 (26%)]	Loss: 0.964644
# Train Epoch: 7 [25600/50000 (51%)]	Loss: 0.935035
# Train Epoch: 7 [38400/50000 (77%)]	Loss: 1.017271
#
# Train set: Average loss: 1.0108, Accuracy: 33626/50000 (67.3%)
#
#
# Test set: Average loss: 0.9844, Accuracy: 6576/10000 (65.760%)
#
# Train Epoch: 8 [0/50000 (0%)]	Loss: 0.777916
# Train Epoch: 8 [12800/50000 (26%)]	Loss: 0.848164
# Train Epoch: 8 [25600/50000 (51%)]	Loss: 0.830740
# Train Epoch: 8 [38400/50000 (77%)]	Loss: 0.856992
#
# Train set: Average loss: 0.7766, Accuracy: 34399/50000 (68.8%)
#
#
# Test set: Average loss: 0.8780, Accuracy: 7026/10000 (70.260%)
#
# Train Epoch: 9 [0/50000 (0%)]	Loss: 0.928819
# Train Epoch: 9 [12800/50000 (26%)]	Loss: 0.698218
# Train Epoch: 9 [25600/50000 (51%)]	Loss: 0.822345
# Train Epoch: 9 [38400/50000 (77%)]	Loss: 0.791190
#
# Train set: Average loss: 0.9671, Accuracy: 34938/50000 (69.9%)
#
#
# Test set: Average loss: 0.8215, Accuracy: 7150/10000 (71.500%)
#
# Train Epoch: 10 [0/50000 (0%)]	Loss: 0.792318
# Train Epoch: 10 [12800/50000 (26%)]	Loss: 0.830630
# Train Epoch: 10 [25600/50000 (51%)]	Loss: 0.918376
# Train Epoch: 10 [38400/50000 (77%)]	Loss: 0.719573
#
# Train set: Average loss: 1.0490, Accuracy: 35341/50000 (70.7%)
#
#
# Test set: Average loss: 0.7876, Accuracy: 7270/10000 (72.700%)
#
# Train Epoch: 11 [0/50000 (0%)]	Loss: 0.787660
# Train Epoch: 11 [12800/50000 (26%)]	Loss: 0.725522
# Train Epoch: 11 [25600/50000 (51%)]	Loss: 0.800123
# Train Epoch: 11 [38400/50000 (77%)]	Loss: 0.864512
#
# Train set: Average loss: 0.8662, Accuracy: 35865/50000 (71.7%)
#
#
# Test set: Average loss: 0.9220, Accuracy: 6881/10000 (68.810%)
#
# Train Epoch: 12 [0/50000 (0%)]	Loss: 0.745175
# Train Epoch: 12 [12800/50000 (26%)]	Loss: 0.737385
# Train Epoch: 12 [25600/50000 (51%)]	Loss: 0.751870
# Train Epoch: 12 [38400/50000 (77%)]	Loss: 0.878545
#
# Train set: Average loss: 0.8637, Accuracy: 36233/50000 (72.5%)
#
#
# Test set: Average loss: 0.9636, Accuracy: 6810/10000 (68.100%)
#
# Train Epoch: 13 [0/50000 (0%)]	Loss: 0.752775
# Train Epoch: 13 [12800/50000 (26%)]	Loss: 0.845008
# Train Epoch: 13 [25600/50000 (51%)]	Loss: 0.812431
# Train Epoch: 13 [38400/50000 (77%)]	Loss: 0.735982
#
# Train set: Average loss: 0.7578, Accuracy: 36356/50000 (72.7%)
#
#
# Test set: Average loss: 0.7731, Accuracy: 7364/10000 (73.640%)
#
# Train Epoch: 14 [0/50000 (0%)]	Loss: 0.780478
# Train Epoch: 14 [12800/50000 (26%)]	Loss: 0.668852
# Train Epoch: 14 [25600/50000 (51%)]	Loss: 0.771922
# Train Epoch: 14 [38400/50000 (77%)]	Loss: 0.762187
#
# Train set: Average loss: 0.7270, Accuracy: 36690/50000 (73.4%)
#
#
# Test set: Average loss: 0.7985, Accuracy: 7301/10000 (73.010%)
#
# Train Epoch: 15 [0/50000 (0%)]	Loss: 0.757801
# Train Epoch: 15 [12800/50000 (26%)]	Loss: 0.754384
# Train Epoch: 15 [25600/50000 (51%)]	Loss: 0.781632
# Train Epoch: 15 [38400/50000 (77%)]	Loss: 0.847104
#
# Train set: Average loss: 0.6236, Accuracy: 36779/50000 (73.6%)
#
#
# Test set: Average loss: 0.7659, Accuracy: 7402/10000 (74.020%)
#
# Train Epoch: 16 [0/50000 (0%)]	Loss: 0.726171
# Train Epoch: 16 [12800/50000 (26%)]	Loss: 0.811475
# Train Epoch: 16 [25600/50000 (51%)]	Loss: 0.594231
# Train Epoch: 16 [38400/50000 (77%)]	Loss: 0.694271
#
# Train set: Average loss: 0.8505, Accuracy: 37022/50000 (74.0%)
#
#
# Test set: Average loss: 0.8400, Accuracy: 7165/10000 (71.650%)
#
# Train Epoch: 17 [0/50000 (0%)]	Loss: 0.606911
# Train Epoch: 17 [12800/50000 (26%)]	Loss: 0.803443
# Train Epoch: 17 [25600/50000 (51%)]	Loss: 0.601547
# Train Epoch: 17 [38400/50000 (77%)]	Loss: 0.757120
#
# Train set: Average loss: 0.6232, Accuracy: 37325/50000 (74.7%)
#
#
# Test set: Average loss: 0.8685, Accuracy: 7111/10000 (71.110%)
#
# Train Epoch: 18 [0/50000 (0%)]	Loss: 0.749815
# Train Epoch: 18 [12800/50000 (26%)]	Loss: 0.706160
# Train Epoch: 18 [25600/50000 (51%)]	Loss: 0.631748
# Train Epoch: 18 [38400/50000 (77%)]	Loss: 0.742890
#
# Train set: Average loss: 0.6444, Accuracy: 37398/50000 (74.8%)
#
#
# Test set: Average loss: 1.0436, Accuracy: 6532/10000 (65.320%)
#
# Train Epoch: 19 [0/50000 (0%)]	Loss: 0.864033
# Train Epoch: 19 [12800/50000 (26%)]	Loss: 0.764810
# Train Epoch: 19 [25600/50000 (51%)]	Loss: 0.854069
# Train Epoch: 19 [38400/50000 (77%)]	Loss: 0.623627
#
# Train set: Average loss: 0.7897, Accuracy: 37571/50000 (75.1%)
#
#
# Test set: Average loss: 0.8388, Accuracy: 7138/10000 (71.380%)
#
# Train Epoch: 20 [0/50000 (0%)]	Loss: 0.764842
# Train Epoch: 20 [12800/50000 (26%)]	Loss: 0.741342
# Train Epoch: 20 [25600/50000 (51%)]	Loss: 0.753770
# Train Epoch: 20 [38400/50000 (77%)]	Loss: 0.765637
#
# Train set: Average loss: 1.0631, Accuracy: 37648/50000 (75.3%)
#
#
# Test set: Average loss: 0.9076, Accuracy: 6855/10000 (68.550%)
#
# Train Epoch: 21 [0/50000 (0%)]	Loss: 0.837199
# Train Epoch: 21 [12800/50000 (26%)]	Loss: 0.723926
# Train Epoch: 21 [25600/50000 (51%)]	Loss: 0.698559
# Train Epoch: 21 [38400/50000 (77%)]	Loss: 0.596032
#
# Train set: Average loss: 0.6774, Accuracy: 37817/50000 (75.6%)
#
#
# Test set: Average loss: 0.9938, Accuracy: 6683/10000 (66.830%)
#
# Train Epoch: 22 [0/50000 (0%)]	Loss: 0.801628
# Train Epoch: 22 [12800/50000 (26%)]	Loss: 0.779862
# Train Epoch: 22 [25600/50000 (51%)]	Loss: 0.671891
# Train Epoch: 22 [38400/50000 (77%)]	Loss: 0.707930
#
# Train set: Average loss: 0.6572, Accuracy: 37758/50000 (75.5%)
#
#
# Test set: Average loss: 0.7343, Accuracy: 7495/10000 (74.950%)
#
# Train Epoch: 23 [0/50000 (0%)]	Loss: 0.703683
# Train Epoch: 23 [12800/50000 (26%)]	Loss: 0.888273
# Train Epoch: 23 [25600/50000 (51%)]	Loss: 0.882969
# Train Epoch: 23 [38400/50000 (77%)]	Loss: 0.672135
#
# Train set: Average loss: 0.6087, Accuracy: 37959/50000 (75.9%)
#
#
# Test set: Average loss: 0.7328, Accuracy: 7493/10000 (74.930%)
#
# Train Epoch: 24 [0/50000 (0%)]	Loss: 0.678804
# Train Epoch: 24 [12800/50000 (26%)]	Loss: 0.788871
# Train Epoch: 24 [25600/50000 (51%)]	Loss: 0.749522
# Train Epoch: 24 [38400/50000 (77%)]	Loss: 0.565482
#
# Train set: Average loss: 0.7981, Accuracy: 38056/50000 (76.1%)
#
#
# Test set: Average loss: 0.7715, Accuracy: 7306/10000 (73.060%)
#
# Train Epoch: 25 [0/50000 (0%)]	Loss: 0.625973
# Train Epoch: 25 [12800/50000 (26%)]	Loss: 0.876445
# Train Epoch: 25 [25600/50000 (51%)]	Loss: 0.608480
# Train Epoch: 25 [38400/50000 (77%)]	Loss: 0.669481
#
# Train set: Average loss: 0.5854, Accuracy: 38061/50000 (76.1%)
#
#
# Test set: Average loss: 0.8046, Accuracy: 7317/10000 (73.170%)
#
# Train Epoch: 26 [0/50000 (0%)]	Loss: 0.662769
# Train Epoch: 26 [12800/50000 (26%)]	Loss: 0.703449
# Train Epoch: 26 [25600/50000 (51%)]	Loss: 0.601802
# Train Epoch: 26 [38400/50000 (77%)]	Loss: 0.537610
#
# Train set: Average loss: 0.6632, Accuracy: 38123/50000 (76.2%)
#
#
# Test set: Average loss: 0.7174, Accuracy: 7542/10000 (75.420%)
#
# Train Epoch: 27 [0/50000 (0%)]	Loss: 0.608671
# Train Epoch: 27 [12800/50000 (26%)]	Loss: 0.641237
# Train Epoch: 27 [25600/50000 (51%)]	Loss: 0.743474
# Train Epoch: 27 [38400/50000 (77%)]	Loss: 0.639211
#
# Train set: Average loss: 0.5853, Accuracy: 38334/50000 (76.7%)
#
#
# Test set: Average loss: 0.7465, Accuracy: 7455/10000 (74.550%)
#
# Train Epoch: 28 [0/50000 (0%)]	Loss: 0.634113
# Train Epoch: 28 [12800/50000 (26%)]	Loss: 0.518130
# Train Epoch: 28 [25600/50000 (51%)]	Loss: 0.770316
# Train Epoch: 28 [38400/50000 (77%)]	Loss: 0.601200
#
# Train set: Average loss: 0.5888, Accuracy: 38334/50000 (76.7%)
#
#
# Test set: Average loss: 0.7988, Accuracy: 7394/10000 (73.940%)
#
# Train Epoch: 29 [0/50000 (0%)]	Loss: 0.668706
# Train Epoch: 29 [12800/50000 (26%)]	Loss: 0.622887
# Train Epoch: 29 [25600/50000 (51%)]	Loss: 0.673807
# Train Epoch: 29 [38400/50000 (77%)]	Loss: 0.751142
#
# Train set: Average loss: 0.9284, Accuracy: 38206/50000 (76.4%)
#
#
# Test set: Average loss: 0.7648, Accuracy: 7394/10000 (73.940%)
#
# Train Epoch: 30 [0/50000 (0%)]	Loss: 0.585379
# Train Epoch: 30 [12800/50000 (26%)]	Loss: 0.795007
# Train Epoch: 30 [25600/50000 (51%)]	Loss: 0.729233
# Train Epoch: 30 [38400/50000 (77%)]	Loss: 0.658064
#
# Train set: Average loss: 0.7349, Accuracy: 38394/50000 (76.8%)
#
#
# Test set: Average loss: 0.7911, Accuracy: 7365/10000 (73.650%)
#
# Train Epoch: 31 [0/50000 (0%)]	Loss: 0.700216
# Train Epoch: 31 [12800/50000 (26%)]	Loss: 0.718354
# Train Epoch: 31 [25600/50000 (51%)]	Loss: 0.463277
# Train Epoch: 31 [38400/50000 (77%)]	Loss: 0.631279
#
# Train set: Average loss: 0.7750, Accuracy: 38508/50000 (77.0%)
#
#
# Test set: Average loss: 0.7976, Accuracy: 7263/10000 (72.630%)
#
# Train Epoch: 32 [0/50000 (0%)]	Loss: 0.757809
# Train Epoch: 32 [12800/50000 (26%)]	Loss: 0.628231
# Train Epoch: 32 [25600/50000 (51%)]	Loss: 0.696894
# Train Epoch: 32 [38400/50000 (77%)]	Loss: 0.582702
#
# Train set: Average loss: 0.6876, Accuracy: 38598/50000 (77.2%)
#
#
# Test set: Average loss: 0.7955, Accuracy: 7345/10000 (73.450%)
#
# Train Epoch: 33 [0/50000 (0%)]	Loss: 0.770073
# Train Epoch: 33 [12800/50000 (26%)]	Loss: 0.546710
# Train Epoch: 33 [25600/50000 (51%)]	Loss: 0.640475
# Train Epoch: 33 [38400/50000 (77%)]	Loss: 0.651883
#
# Train set: Average loss: 0.7546, Accuracy: 38583/50000 (77.2%)
#
#
# Test set: Average loss: 0.8352, Accuracy: 7199/10000 (71.990%)
#
# Train Epoch: 34 [0/50000 (0%)]	Loss: 0.707846
# Train Epoch: 34 [12800/50000 (26%)]	Loss: 0.695758
# Train Epoch: 34 [25600/50000 (51%)]	Loss: 0.631320
# Train Epoch: 34 [38400/50000 (77%)]	Loss: 0.735694
#
# Train set: Average loss: 0.8149, Accuracy: 38635/50000 (77.3%)
#
#
# Test set: Average loss: 0.6511, Accuracy: 7791/10000 (77.910%)
#
# Train Epoch: 35 [0/50000 (0%)]	Loss: 0.606026
# Train Epoch: 35 [12800/50000 (26%)]	Loss: 0.776548
# Train Epoch: 35 [25600/50000 (51%)]	Loss: 0.656383
# Train Epoch: 35 [38400/50000 (77%)]	Loss: 0.710698
#
# Train set: Average loss: 0.5367, Accuracy: 38660/50000 (77.3%)
#
#
# Test set: Average loss: 0.8069, Accuracy: 7225/10000 (72.250%)
#
# Train Epoch: 36 [0/50000 (0%)]	Loss: 0.558270
# Train Epoch: 36 [12800/50000 (26%)]	Loss: 0.645672
# Train Epoch: 36 [25600/50000 (51%)]	Loss: 0.723956
# Train Epoch: 36 [38400/50000 (77%)]	Loss: 0.854721
#
# Train set: Average loss: 0.7503, Accuracy: 38787/50000 (77.6%)
#
#
# Test set: Average loss: 0.7168, Accuracy: 7522/10000 (75.220%)
#
# Train Epoch: 37 [0/50000 (0%)]	Loss: 0.677905
# Train Epoch: 37 [12800/50000 (26%)]	Loss: 0.903478
# Train Epoch: 37 [25600/50000 (51%)]	Loss: 0.675027
# Train Epoch: 37 [38400/50000 (77%)]	Loss: 0.609131
#
# Train set: Average loss: 0.6406, Accuracy: 38810/50000 (77.6%)
#
#
# Test set: Average loss: 0.7790, Accuracy: 7369/10000 (73.690%)
#
# Train Epoch: 38 [0/50000 (0%)]	Loss: 0.538738
# Train Epoch: 38 [12800/50000 (26%)]	Loss: 0.564649
# Train Epoch: 38 [25600/50000 (51%)]	Loss: 0.469426
# Train Epoch: 38 [38400/50000 (77%)]	Loss: 0.744936
#
# Train set: Average loss: 0.6595, Accuracy: 38924/50000 (77.8%)
#
#
# Test set: Average loss: 0.7244, Accuracy: 7546/10000 (75.460%)
#
# Train Epoch: 39 [0/50000 (0%)]	Loss: 0.436360
# Train Epoch: 39 [12800/50000 (26%)]	Loss: 0.623969
# Train Epoch: 39 [25600/50000 (51%)]	Loss: 0.647370
# Train Epoch: 39 [38400/50000 (77%)]	Loss: 0.598907
#
# Train set: Average loss: 0.7500, Accuracy: 38810/50000 (77.6%)
#
#
# Test set: Average loss: 0.7421, Accuracy: 7440/10000 (74.400%)
#
# Train Epoch: 40 [0/50000 (0%)]	Loss: 0.704637
# Train Epoch: 40 [12800/50000 (26%)]	Loss: 0.494535
# Train Epoch: 40 [25600/50000 (51%)]	Loss: 0.698451
# Train Epoch: 40 [38400/50000 (77%)]	Loss: 0.601464
#
# Train set: Average loss: 0.7628, Accuracy: 38968/50000 (77.9%)
#
#
# Test set: Average loss: 0.7159, Accuracy: 7589/10000 (75.890%)
#
# Train Epoch: 41 [0/50000 (0%)]	Loss: 0.755075
# Train Epoch: 41 [12800/50000 (26%)]	Loss: 0.696177
# Train Epoch: 41 [25600/50000 (51%)]	Loss: 0.597161
# Train Epoch: 41 [38400/50000 (77%)]	Loss: 0.652550
#
# Train set: Average loss: 0.6668, Accuracy: 39033/50000 (78.1%)
#
#
# Test set: Average loss: 0.7379, Accuracy: 7481/10000 (74.810%)
#
# Train Epoch: 42 [0/50000 (0%)]	Loss: 0.537787
# Train Epoch: 42 [12800/50000 (26%)]	Loss: 0.750195
# Train Epoch: 42 [25600/50000 (51%)]	Loss: 0.849936
# Train Epoch: 42 [38400/50000 (77%)]	Loss: 0.580971
#
# Train set: Average loss: 0.7897, Accuracy: 38959/50000 (77.9%)
#
#
# Test set: Average loss: 0.7276, Accuracy: 7495/10000 (74.950%)
#
# Train Epoch: 43 [0/50000 (0%)]	Loss: 0.437376
# Train Epoch: 43 [12800/50000 (26%)]	Loss: 0.760358
# Train Epoch: 43 [25600/50000 (51%)]	Loss: 0.755016
# Train Epoch: 43 [38400/50000 (77%)]	Loss: 0.693349
#
# Train set: Average loss: 0.6108, Accuracy: 38975/50000 (78.0%)
#
#
# Test set: Average loss: 0.7585, Accuracy: 7491/10000 (74.910%)
#
# Train Epoch: 44 [0/50000 (0%)]	Loss: 0.626465
# Train Epoch: 44 [12800/50000 (26%)]	Loss: 0.560573
# Train Epoch: 44 [25600/50000 (51%)]	Loss: 0.435887
# Train Epoch: 44 [38400/50000 (77%)]	Loss: 0.563587
#
# Train set: Average loss: 0.5854, Accuracy: 39050/50000 (78.1%)
#
#
# Test set: Average loss: 0.7419, Accuracy: 7530/10000 (75.300%)
#
# Train Epoch: 45 [0/50000 (0%)]	Loss: 0.690214
# Train Epoch: 45 [12800/50000 (26%)]	Loss: 0.688393
# Train Epoch: 45 [25600/50000 (51%)]	Loss: 0.546556
# Train Epoch: 45 [38400/50000 (77%)]	Loss: 0.653478
#
# Train set: Average loss: 0.7565, Accuracy: 39083/50000 (78.2%)
#
#
# Test set: Average loss: 0.6737, Accuracy: 7731/10000 (77.310%)
#
# Train Epoch: 46 [0/50000 (0%)]	Loss: 0.523741
# Train Epoch: 46 [12800/50000 (26%)]	Loss: 0.720624
# Train Epoch: 46 [25600/50000 (51%)]	Loss: 0.810764
# Train Epoch: 46 [38400/50000 (77%)]	Loss: 0.715691
#
# Train set: Average loss: 0.6284, Accuracy: 39200/50000 (78.4%)
#
#
# Test set: Average loss: 0.7477, Accuracy: 7507/10000 (75.070%)
#
# Train Epoch: 47 [0/50000 (0%)]	Loss: 0.582291
# Train Epoch: 47 [12800/50000 (26%)]	Loss: 0.577291
# Train Epoch: 47 [25600/50000 (51%)]	Loss: 0.508338
# Train Epoch: 47 [38400/50000 (77%)]	Loss: 0.630574
#
# Train set: Average loss: 0.6913, Accuracy: 39198/50000 (78.4%)
#
#
# Test set: Average loss: 0.6903, Accuracy: 7687/10000 (76.870%)
#
# Train Epoch: 48 [0/50000 (0%)]	Loss: 0.688591
# Train Epoch: 48 [12800/50000 (26%)]	Loss: 0.611078
# Train Epoch: 48 [25600/50000 (51%)]	Loss: 0.770338
# Train Epoch: 48 [38400/50000 (77%)]	Loss: 0.468505
#
# Train set: Average loss: 0.7017, Accuracy: 39395/50000 (78.8%)
#
#
# Test set: Average loss: 0.7670, Accuracy: 7406/10000 (74.060%)
#
# Train Epoch: 49 [0/50000 (0%)]	Loss: 0.463090
# Train Epoch: 49 [12800/50000 (26%)]	Loss: 0.640989
# Train Epoch: 49 [25600/50000 (51%)]	Loss: 0.556103
# Train Epoch: 49 [38400/50000 (77%)]	Loss: 0.586507
#
# Train set: Average loss: 0.5860, Accuracy: 39394/50000 (78.8%)
#
#
# Test set: Average loss: 0.7070, Accuracy: 7599/10000 (75.990%)
#
# Train Epoch: 50 [0/50000 (0%)]	Loss: 0.688722
# Train Epoch: 50 [12800/50000 (26%)]	Loss: 0.482067
# Train Epoch: 50 [25600/50000 (51%)]	Loss: 0.689596
# Train Epoch: 50 [38400/50000 (77%)]	Loss: 0.619831
#
# Train set: Average loss: 0.5803, Accuracy: 39332/50000 (78.7%)
#
#
# Test set: Average loss: 0.7502, Accuracy: 7454/10000 (74.540%)

# %% [markdown]
# This should get us well above 75%, the best we got was ~ 80%.
#
# Now, use different torchvision architectures, different optimizers (Adam is always a good choice), data augmentation techniques, and hyperparameter search to achieve a test accuracy of >90 %
